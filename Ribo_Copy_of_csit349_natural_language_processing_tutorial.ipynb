# %% [markdown]
# #Natural Language Processing (NLP) with Python - Tutorial
#
# * Tutorial: https://colab.research.google.com/drive/1vt4u8Hp-iQIRSFc633Outvl7t3R34-iJ?usp=sharing#scrollTo=8CbkQnvBVXPv
#
# * Github: https://github.com/towardsai/tutorials/tree/master/natural_language_processing

# %%
#To get the text file used :
# !wget https://raw.githubusercontent.com/8maaan/nlp-tutorial/main/sample_text.txt

#To get the image file used :
# !wget https://raw.githubusercontent.com/towardsai/tutorials/master/natural_language_processing/circle.png
# Out:
# --2024-04-29 13:28:44--  https://raw.githubusercontent.com/8maaan/nlp-tutorial/main/sample_text.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1211 (1.2K) [text/plain]
# Saving to: ‘sample_text.txt.4’
#
# sample_text.txt.4   100%[===================>]   1.18K  --.-KB/s    in 0s
#
# 2024-04-29 13:28:45 (63.0 MB/s) - ‘sample_text.txt.4’ saved [1211/1211]
#
# --2024-04-29 13:28:45--  https://raw.githubusercontent.com/towardsai/tutorials/master/natural_language_processing/circle.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9175 (9.0K) [image/png]
# Saving to: ‘circle.png.6’
#
# circle.png.6        100%[===================>]   8.96K  --.-KB/s    in 0s
#
# 2024-04-29 13:28:45 (65.1 MB/s) - ‘circle.png.6’ saved [9175/9175]

# %%
#Open the text file :
text_file = open("sample_text.txt")

#Read the data :
text = text_file.read()

#Datatype of the data read :
print (type(text))
print("\n")

#Print the text :
print(text)
print("\n")
#Length of the text :
print (len(text))
# Out:
# <class 'str'>
#
#
# Set sail for the Grand Line, where dreams become reality and legends are born! In the world of One Piece, courage is not the absence of fear, but the triumph over it. It's about facing your fears, chasing your dreams, and never giving up, no matter the odds. As Monkey D. Luffy once said, 'I don't want to conquer anything. I just think the guy with the most freedom in this whole ocean... is the Pirate King!' It's a reminder that true freedom lies in following your heart and forging your own path, even if it means defying the odds and challenging the mightiest foes.
#
# But remember, the journey to the top is fraught with challenges and adversaries. As Roronoa Zoro teaches us, 'Being strong isn't just about having power or skill... It's about being able to protect those you care about.' In the world of One Piece, friendship, loyalty, and determination are as valuable as any treasure. And as the Straw Hat Pirates continue their adventure, they show us that even in the darkest of times, there's always a glimmer of hope if you have the will to keep moving forward. So let the winds of destiny carry you towards your dreams, for in the end, it's not the destination that matters, but the journey itself.
#
#
#
# 1211

# %%
#Import required libraries :
import nltk
from nltk import sent_tokenize
from nltk import word_tokenize


import nltk
nltk.download("popular")
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to /root/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to /root/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to /root/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to /root/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to /root/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /root/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to /root/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to /root/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to /root/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /root/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to /root/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to /root/nltk_data...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to /root/nltk_data...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to /root/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /root/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /root/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# True

# %%
#Tokenize the text by sentences :
sentences = sent_tokenize(text)

#How many sentences are there? :
print (len(sentences))

#Print the sentences :
#print(sentences)
sentences
# Out:
# 12
# ['Set sail for the Grand Line, where dreams become reality and legends are born!',
#  'In the world of One Piece, courage is not the absence of fear, but the triumph over it.',
#  "It's about facing your fears, chasing your dreams, and never giving up, no matter the odds.",
#  "As Monkey D. Luffy once said, 'I don't want to conquer anything.",
#  "I just think the guy with the most freedom in this whole ocean... is the Pirate King!'",
#  "It's a reminder that true freedom lies in following your heart and forging your own path, even if it means defying the odds and challenging the mightiest foes.",
#  'But remember, the journey to the top is fraught with challenges and adversaries.',
#  "As Roronoa Zoro teaches us, 'Being strong isn't just about having power or skill...",
#  "It's about being able to protect those you care about.'",
#  'In the world of One Piece, friendship, loyalty, and determination are as valuable as any treasure.',
#  "And as the Straw Hat Pirates continue their adventure, they show us that even in the darkest of times, there's always a glimmer of hope if you have the will to keep moving forward.",
#  "So let the winds of destiny carry you towards your dreams, for in the end, it's not the destination that matters, but the journey itself."]

# %%
#Tokenize the text with words :
words = word_tokenize(text)

#How many words are there? :
print (len(words))
print("\n")

#Print words :
print (words)
# Out:
# 258
#
#
# ['Set', 'sail', 'for', 'the', 'Grand', 'Line', ',', 'where', 'dreams', 'become', 'reality', 'and', 'legends', 'are', 'born', '!', 'In', 'the', 'world', 'of', 'One', 'Piece', ',', 'courage', 'is', 'not', 'the', 'absence', 'of', 'fear', ',', 'but', 'the', 'triumph', 'over', 'it', '.', 'It', "'s", 'about', 'facing', 'your', 'fears', ',', 'chasing', 'your', 'dreams', ',', 'and', 'never', 'giving', 'up', ',', 'no', 'matter', 'the', 'odds', '.', 'As', 'Monkey', 'D.', 'Luffy', 'once', 'said', ',', "'", 'I', 'do', "n't", 'want', 'to', 'conquer', 'anything', '.', 'I', 'just', 'think', 'the', 'guy', 'with', 'the', 'most', 'freedom', 'in', 'this', 'whole', 'ocean', '...', 'is', 'the', 'Pirate', 'King', '!', "'", 'It', "'s", 'a', 'reminder', 'that', 'true', 'freedom', 'lies', 'in', 'following', 'your', 'heart', 'and', 'forging', 'your', 'own', 'path', ',', 'even', 'if', 'it', 'means', 'defying', 'the', 'odds', 'and', 'challenging', 'the', 'mightiest', 'foes', '.', 'But', 'remember', ',', 'the', 'journey', 'to', 'the', 'top', 'is', 'fraught', 'with', 'challenges', 'and', 'adversaries', '.', 'As', 'Roronoa', 'Zoro', 'teaches', 'us', ',', "'Being", 'strong', 'is', "n't", 'just', 'about', 'having', 'power', 'or', 'skill', '...', 'It', "'s", 'about', 'being', 'able', 'to', 'protect', 'those', 'you', 'care', 'about', '.', "'", 'In', 'the', 'world', 'of', 'One', 'Piece', ',', 'friendship', ',', 'loyalty', ',', 'and', 'determination', 'are', 'as', 'valuable', 'as', 'any', 'treasure', '.', 'And', 'as', 'the', 'Straw', 'Hat', 'Pirates', 'continue', 'their', 'adventure', ',', 'they', 'show', 'us', 'that', 'even', 'in', 'the', 'darkest', 'of', 'times', ',', 'there', "'s", 'always', 'a', 'glimmer', 'of', 'hope', 'if', 'you', 'have', 'the', 'will', 'to', 'keep', 'moving', 'forward', '.', 'So', 'let', 'the', 'winds', 'of', 'destiny', 'carry', 'you', 'towards', 'your', 'dreams', ',', 'for', 'in', 'the', 'end', ',', 'it', "'s", 'not', 'the', 'destination', 'that', 'matters', ',', 'but', 'the', 'journey', 'itself', '.']

# %%
#Import required libraries :
from nltk.probability import FreqDist

#Find the frequency :
fdist = FreqDist(words)

#Print 10 most common words :
fdist.most_common(10)
# Out:
# [('the', 20),
#  (',', 18),
#  ('.', 9),
#  ('and', 6),
#  ('of', 6),
#  ("'s", 5),
#  ('your', 5),
#  ('is', 4),
#  ('about', 4),
#  ('to', 4)]

# %%
#Plot the graph for fdist :
import matplotlib.pyplot as plt

fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Empty list to store words:
words_no_punc = []

#Removing punctuation marks :
for w in words:
    if w.isalpha():
        words_no_punc.append(w.lower())

#Print the words without punctution marks :
print (words_no_punc)

print ("\n")

#Length :
print (len(words_no_punc))
# Out:
# ['set', 'sail', 'for', 'the', 'grand', 'line', 'where', 'dreams', 'become', 'reality', 'and', 'legends', 'are', 'born', 'in', 'the', 'world', 'of', 'one', 'piece', 'courage', 'is', 'not', 'the', 'absence', 'of', 'fear', 'but', 'the', 'triumph', 'over', 'it', 'it', 'about', 'facing', 'your', 'fears', 'chasing', 'your', 'dreams', 'and', 'never', 'giving', 'up', 'no', 'matter', 'the', 'odds', 'as', 'monkey', 'luffy', 'once', 'said', 'i', 'do', 'want', 'to', 'conquer', 'anything', 'i', 'just', 'think', 'the', 'guy', 'with', 'the', 'most', 'freedom', 'in', 'this', 'whole', 'ocean', 'is', 'the', 'pirate', 'king', 'it', 'a', 'reminder', 'that', 'true', 'freedom', 'lies', 'in', 'following', 'your', 'heart', 'and', 'forging', 'your', 'own', 'path', 'even', 'if', 'it', 'means', 'defying', 'the', 'odds', 'and', 'challenging', 'the', 'mightiest', 'foes', 'but', 'remember', 'the', 'journey', 'to', 'the', 'top', 'is', 'fraught', 'with', 'challenges', 'and', 'adversaries', 'as', 'roronoa', 'zoro', 'teaches', 'us', 'strong', 'is', 'just', 'about', 'having', 'power', 'or', 'skill', 'it', 'about', 'being', 'able', 'to', 'protect', 'those', 'you', 'care', 'about', 'in', 'the', 'world', 'of', 'one', 'piece', 'friendship', 'loyalty', 'and', 'determination', 'are', 'as', 'valuable', 'as', 'any', 'treasure', 'and', 'as', 'the', 'straw', 'hat', 'pirates', 'continue', 'their', 'adventure', 'they', 'show', 'us', 'that', 'even', 'in', 'the', 'darkest', 'of', 'times', 'there', 'always', 'a', 'glimmer', 'of', 'hope', 'if', 'you', 'have', 'the', 'will', 'to', 'keep', 'moving', 'forward', 'so', 'let', 'the', 'winds', 'of', 'destiny', 'carry', 'you', 'towards', 'your', 'dreams', 'for', 'in', 'the', 'end', 'it', 'not', 'the', 'destination', 'that', 'matters', 'but', 'the', 'journey', 'itself']
#
#
# 215

# %%
#Frequency distribution :
fdist = FreqDist(words_no_punc)

fdist.most_common(10)
# Out:
# [('the', 20),
#  ('and', 7),
#  ('in', 6),
#  ('of', 6),
#  ('it', 6),
#  ('your', 5),
#  ('as', 5),
#  ('is', 4),
#  ('about', 4),
#  ('to', 4)]

# %%
#Plot the most common words on grpah:

fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from nltk.corpus import stopwords

#List of stopwords
stopwords = stopwords.words("english")
print(stopwords)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
#Empty list to store clean words :
clean_words = []

for w in words_no_punc:
    if w not in stopwords:
        clean_words.append(w)

print(clean_words)
print("\n")
print(len(clean_words))
# Out:
# ['set', 'sail', 'grand', 'line', 'dreams', 'become', 'reality', 'legends', 'born', 'world', 'one', 'piece', 'courage', 'absence', 'fear', 'triumph', 'facing', 'fears', 'chasing', 'dreams', 'never', 'giving', 'matter', 'odds', 'monkey', 'luffy', 'said', 'want', 'conquer', 'anything', 'think', 'guy', 'freedom', 'whole', 'ocean', 'pirate', 'king', 'reminder', 'true', 'freedom', 'lies', 'following', 'heart', 'forging', 'path', 'even', 'means', 'defying', 'odds', 'challenging', 'mightiest', 'foes', 'remember', 'journey', 'top', 'fraught', 'challenges', 'adversaries', 'roronoa', 'zoro', 'teaches', 'us', 'strong', 'power', 'skill', 'able', 'protect', 'care', 'world', 'one', 'piece', 'friendship', 'loyalty', 'determination', 'valuable', 'treasure', 'straw', 'hat', 'pirates', 'continue', 'adventure', 'show', 'us', 'even', 'darkest', 'times', 'always', 'glimmer', 'hope', 'keep', 'moving', 'forward', 'let', 'winds', 'destiny', 'carry', 'towards', 'dreams', 'end', 'destination', 'matters', 'journey']
#
#
# 102

# %%
#Frequency distribution :
fdist = FreqDist(clean_words)

fdist.most_common(10)
# Out:
# [('dreams', 3),
#  ('world', 2),
#  ('one', 2),
#  ('piece', 2),
#  ('odds', 2),
#  ('freedom', 2),
#  ('even', 2),
#  ('journey', 2),
#  ('us', 2),
#  ('set', 1)]

# %%
#Plot the most common words on grpah:

fdist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
#Library to form wordcloud :
from wordcloud import WordCloud

#Library to plot the wordcloud :
import matplotlib.pyplot as plt

#Generating the wordcloud :
wordcloud = WordCloud().generate(text)

#Plot the wordcloud :
plt.figure(figsize = (12, 12))
plt.imshow(wordcloud)

#To remove the axis value :
plt.axis("off")
plt.show()

# %%
#Import required libraries :
import numpy as np
from PIL import Image
from wordcloud import WordCloud

#Here we are going to use a circle image as mask :
char_mask = np.array(Image.open("circle.png"))

#Generating wordcloud :
wordcloud = WordCloud(background_color="black",mask=char_mask).generate(text)

#Plot the wordcloud :
plt.figure(figsize = (8,8))
plt.imshow(wordcloud)

#To remove the axis value :
plt.axis("off")
plt.show()

# %%
#Stemming Example :

#Import stemming library :
from nltk.stem import PorterStemmer

porter = PorterStemmer()

#Word-list for stemming :
# word_list = ["Study","Studying","Studies","Studied"]

word_list = ["Try","Trying","Tries","Tried"]

for w in word_list:
    print(porter.stem(w))
# Out:
# tri
# tri
# tri
# tri

# %%
#Stemming Example :

#Import stemming library :
from nltk.stem import PorterStemmer

porter = PorterStemmer()

#Word-list for stemming :
# word_list = ["studies","leaves","decreases","plays"]
word_list = ["tries","eats","goes","sings"]

for w in word_list:
    print(porter.stem(w))
# Out:
# tri
# eat
# goe
# sing

# %%
#Stemming Example :

#Import stemming library :
from nltk.stem import SnowballStemmer

snowball = SnowballStemmer("english")

#Word-list for stemming :
# word_list = ["Study","Studying","Studies","Studied"]

word_list = ["Dance","Dancing","Dances","Danced"]

for w in word_list:
    print(snowball.stem(w))
# Out:
# danc
# danc
# danc
# danc

# %%
#Stemming Example :

#Import stemming library :
from nltk.stem import SnowballStemmer

#Print languages supported :
SnowballStemmer.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
from nltk import WordNetLemmatizer

lemma = WordNetLemmatizer()
# word_list = ["Study","Studying","Studies","Studied"]
word_list = ["Dance","Dancing","Dances","Danced"]

for w in word_list:
    print(lemma.lemmatize(w ,pos="v"))
# Out:
# Dance
# Dancing
# Dances
# Danced

# %%
from nltk import WordNetLemmatizer

lemma = WordNetLemmatizer()
word_list = ["am","is","are","was","were"]

for w in word_list:
    print(lemma.lemmatize(w ,pos="v"))
# Out:
# be
# be
# be
# be
# be

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# print(stemmer.stem('studies'))
print(stemmer.stem('plays'))
print(stemmer.stem('goes'))
# Out:
# play
# goe

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# print(lemmatizer.lemmatize('studies'))
print(lemmatizer.lemmatize('plays'))
print(lemmatizer.lemmatize('goes'))
# Out:
# play
# go

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize('studies'))
# Out:
# study

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize('typing', pos="v"))
print(lemmatizer.lemmatize('typing', pos="n"))
print(lemmatizer.lemmatize('typing', pos="a"))
print(lemmatizer.lemmatize('typing', pos="r"))
# Out:
# type
# typing
# typing
# typing

# %%
from nltk import WordNetLemmatizer

lemma = WordNetLemmatizer()
word_list = ["studies","leaves","decreases","plays"]

for w in word_list:
    print(lemma.lemmatize(w))
# Out:
# study
# leaf
# decrease
# play

# %%
#PoS tagging :
tag = nltk.pos_tag(["Studying","Study"])
print (tag)
# Out:
# [('Studying', 'VBG'), ('Study', 'NN')]

# %%
#PoS tagging example :

sentence = "A very beautiful young lady is walking on the beach"

#Tokenizing words :
tokenized_words = word_tokenize(sentence)

for words in tokenized_words:
    tagged_words = nltk.pos_tag(tokenized_words)

tagged_words
# Out:
# [('A', 'DT'),
#  ('very', 'RB'),
#  ('beautiful', 'JJ'),
#  ('young', 'JJ'),
#  ('lady', 'NN'),
#  ('is', 'VBZ'),
#  ('walking', 'VBG'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('beach', 'NN')]

# %%
#Extracting Noun Phrase from text :

# ? - optional character
# * - 0 or more repetations
grammar = "NP : {<DT>?<JJ>*<NN>} "
import matplotlib.pyplot as plt
#Creating a parser :
parser = nltk.RegexpParser(grammar)

#Parsing text :
output = parser.parse(tagged_words)
print (output)

#To visualize :
#output.draw()
# Out:
# (S
#   A/DT
#   very/RB
#   (NP beautiful/JJ young/JJ lady/NN)
#   is/VBZ
#   walking/VBG
#   on/IN
#   (NP the/DT beach/NN))

# %%
#Sentence for NER :
# sentence = "Mr. Smith made a deal on a beach of Switzerland near WHO."
sentence = "Ms. Topaz suddenly came to my house and asked me to join the IPC."

#Tokenizing words :
tokenized_words = word_tokenize(sentence)

#PoS tagging :
for w in tokenized_words:
    tagged_words = nltk.pos_tag(tokenized_words)

print (tagged_words)

#Named Entity Recognition :
N_E_R = nltk.ne_chunk(tagged_words,binary=False)
print(N_E_R)

#To visualize :
#N_E_R.draw()
# Out:
# [('Ms.', 'NNP'), ('Topaz', 'NNP'), ('suddenly', 'RB'), ('came', 'VBD'), ('to', 'TO'), ('my', 'PRP$'), ('house', 'NN'), ('and', 'CC'), ('asked', 'VBD'), ('me', 'PRP'), ('to', 'TO'), ('join', 'VB'), ('the', 'DT'), ('IPC', 'NNP'), ('.', '.')]
# (S
#   Ms./NNP
#   Topaz/NNP
#   suddenly/RB
#   came/VBD
#   to/TO
#   my/PRP$
#   house/NN
#   and/CC
#   asked/VBD
#   me/PRP
#   to/TO
#   join/VB
#   the/DT
#   (ORGANIZATION IPC/NNP)
#   ./.)

# %%
#Sentence for NER :
sentence = "Mr. Smith made a deal on a beach of Switzerland near WHO."

#Tokenizing words :
tokenized_words = word_tokenize(sentence)

#PoS tagging :
for w in tokenized_words:
    tagged_words = nltk.pos_tag(tokenized_words)

#print (tagged_words)

#Named Entity Recognition :
N_E_R = nltk.ne_chunk(tagged_words,binary=True)

print(N_E_R)

#To visualize :
# N_E_R.draw()
# Out:
# (S
#   (NE Mr./NNP Smith/NNP)
#   made/VBD
#   a/DT
#   deal/NN
#   on/IN
#   a/DT
#   beach/NN
#   of/IN
#   (NE Switzerland/NNP)
#   near/IN
#   (NE WHO/NNP)
#   ./.)

# %%
#Import wordnet :
from nltk.corpus import wordnet

# for words in wordnet.synsets("Fun"):
#     print(words)
for words in wordnet.synsets("Rage"):
    print(words)
# Out:
# Synset('fury.n.01')
# Synset('rage.n.02')
# Synset('rage.n.03')
# Synset('rage.n.04')
# Synset('fad.n.01')
# Synset('ramp.v.01')
# Synset('rage.v.02')
# Synset('rage.v.03')

# %%
#Word meaning with definitions :
# for words in wordnet.synsets("Fun"):
for words in wordnet.synsets("Cat"):
    print(words.name())
    print(words.definition())
    print(words.examples())

    for lemma in words.lemmas():
        print(lemma)
    print("\n")
# Out:
# cat.n.01
# feline mammal usually having thick soft fur and no ability to roar: domestic cats; wildcats
# []
# Lemma('cat.n.01.cat')
# Lemma('cat.n.01.true_cat')
#
#
# guy.n.01
# an informal term for a youth or man
# ['a nice guy', "the guy's only doing it for some doll"]
# Lemma('guy.n.01.guy')
# Lemma('guy.n.01.cat')
# Lemma('guy.n.01.hombre')
# Lemma('guy.n.01.bozo')
#
#
# cat.n.03
# a spiteful woman gossip
# ['what a cat she is!']
# Lemma('cat.n.03.cat')
#
#
# kat.n.01
# the leaves of the shrub Catha edulis which are chewed like tobacco or used to make tea; has the effect of a euphoric stimulant
# ['in Yemen kat is used daily by 85% of adults']
# Lemma('kat.n.01.kat')
# Lemma('kat.n.01.khat')
# Lemma('kat.n.01.qat')
# Lemma('kat.n.01.quat')
# Lemma('kat.n.01.cat')
# Lemma('kat.n.01.Arabian_tea')
# Lemma('kat.n.01.African_tea')
#
#
# cat-o'-nine-tails.n.01
# a whip with nine knotted cords
# ['British sailors feared the cat']
# Lemma('cat-o'-nine-tails.n.01.cat-o'-nine-tails')
# Lemma('cat-o'-nine-tails.n.01.cat')
#
#
# caterpillar.n.02
# a large tracked vehicle that is propelled by two endless metal belts; frequently used for moving earth in construction and farm work
# []
# Lemma('caterpillar.n.02.Caterpillar')
# Lemma('caterpillar.n.02.cat')
#
#
# big_cat.n.01
# any of several large cats typically able to roar and living in the wild
# []
# Lemma('big_cat.n.01.big_cat')
# Lemma('big_cat.n.01.cat')
#
#
# computerized_tomography.n.01
# a method of examining body organs by scanning them with X rays and using a computer to construct a series of cross-sectional scans along a single axis
# []
# Lemma('computerized_tomography.n.01.computerized_tomography')
# Lemma('computerized_tomography.n.01.computed_tomography')
# Lemma('computerized_tomography.n.01.CT')
# Lemma('computerized_tomography.n.01.computerized_axial_tomography')
# Lemma('computerized_tomography.n.01.computed_axial_tomography')
# Lemma('computerized_tomography.n.01.CAT')
#
#
# cat.v.01
# beat with a cat-o'-nine-tails
# []
# Lemma('cat.v.01.cat')
#
#
# vomit.v.01
# eject the contents of the stomach through the mouth
# ['After drinking too much, the students vomited', 'He purged continuously', 'The patient regurgitated the food we gave him last night']
# Lemma('vomit.v.01.vomit')
# Lemma('vomit.v.01.vomit_up')
# Lemma('vomit.v.01.purge')
# Lemma('vomit.v.01.cast')
# Lemma('vomit.v.01.sick')
# Lemma('vomit.v.01.cat')
# Lemma('vomit.v.01.be_sick')
# Lemma('vomit.v.01.disgorge')
# Lemma('vomit.v.01.regorge')
# Lemma('vomit.v.01.retch')
# Lemma('vomit.v.01.puke')
# Lemma('vomit.v.01.barf')
# Lemma('vomit.v.01.spew')
# Lemma('vomit.v.01.spue')
# Lemma('vomit.v.01.chuck')
# Lemma('vomit.v.01.upchuck')
# Lemma('vomit.v.01.honk')
# Lemma('vomit.v.01.regurgitate')
# Lemma('vomit.v.01.throw_up')

# %%
#How many differnt meanings :
# for words in wordnet.synsets("Fun"):
for words in wordnet.synsets("Cool"):
    for lemma in words.lemmas():
        print(lemma)
    print("\n")
# Out:
# Lemma('cool.n.01.cool')
#
#
# Lemma('aplomb.n.01.aplomb')
# Lemma('aplomb.n.01.assuredness')
# Lemma('aplomb.n.01.cool')
# Lemma('aplomb.n.01.poise')
# Lemma('aplomb.n.01.sang-froid')
#
#
# Lemma('cool.v.01.cool')
# Lemma('cool.v.01.chill')
# Lemma('cool.v.01.cool_down')
#
#
# Lemma('cool.v.02.cool')
# Lemma('cool.v.02.chill')
# Lemma('cool.v.02.cool_down')
#
#
# Lemma('cool.v.03.cool')
# Lemma('cool.v.03.cool_off')
# Lemma('cool.v.03.cool_down')
#
#
# Lemma('cool.a.01.cool')
#
#
# Lemma('cool.s.02.cool')
# Lemma('cool.s.02.coolheaded')
# Lemma('cool.s.02.nerveless')
#
#
# Lemma('cool.a.03.cool')
#
#
# Lemma('cool.a.04.cool')
#
#
# Lemma('cool.s.05.cool')
#
#
# Lemma('cool.s.06.cool')

# %%
# word = wordnet.synsets("Play")[0]
word = wordnet.synsets("Love")[0]

#Checking name :
print(word.name())

#Checking definition :
print(word.definition())

#Checking examples:
print(word.examples())
# Out:
# love.n.01
# a strong positive emotion of regard and affection
# ['his love for his work', 'children need a lot of love']

# %%
word = wordnet.synsets("Play")[0]

#Find more abstract term :
print(word.hypernyms())
# Out:
# [Synset('dramatic_composition.n.01')]

# %%
word = wordnet.synsets("Play")[0]

#Find more specific term :
word.hyponyms()
# Out:
# [Synset('grand_guignol.n.01'),
#  Synset('miracle_play.n.01'),
#  Synset('morality_play.n.01'),
#  Synset('mystery_play.n.01'),
#  Synset('passion_play.n.01'),
#  Synset('playlet.n.01'),
#  Synset('satyr_play.n.01'),
#  Synset('theater_of_the_absurd.n.01')]

# %%
word = wordnet.synsets("Play")[0]

#Get only name :
print(word.lemmas()[0].name())
# Out:
# play

# %%
#Finding synonyms :

#Empty list to store synonyms :
synonyms = []

for words in wordnet.synsets('Fun'):
    for lemma in words.lemmas():
        synonyms.append(lemma.name())

synonyms
# Out:
# ['fun',
#  'merriment',
#  'playfulness',
#  'fun',
#  'play',
#  'sport',
#  'fun',
#  'playfulness',
#  'fun']

# %%
#Finding antonyms :

#Empty list to store antonyms :
antonyms = []

for words in wordnet.synsets('Natural'):
    for lemma in words.lemmas():
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

#Print antonyms :
antonyms
# Out:
# ['unnatural', 'artificial', 'supernatural', 'sharp']

# %%
#Finding synonyms and antonyms :

#Empty lists to store synonyms/antonynms :
synonyms = []
antonyms = []

for words in wordnet.synsets('New'):
    for lemma in words.lemmas():
        synonyms.append(lemma.name())
        if lemma.antonyms():
            antonyms.append(lemma.antonyms()[0].name())

#Print lists :
print(synonyms)
print("\n")
print(antonyms)
# Out:
# ['new', 'fresh', 'new', 'novel', 'raw', 'new', 'new', 'unexampled', 'new', 'new', 'newfangled', 'new', 'New', 'Modern', 'New', 'new', 'young', 'new', 'newly', 'freshly', 'fresh', 'new']
#
#
# ['old', 'worn']

# %%
#Similarity in words :
word1 = wordnet.synsets("ship","n")[0]

word2 = wordnet.synsets("boat","n")[0]

#Check similarity :
print(word1.wup_similarity(word2))
# Out:
# 0.9090909090909091

# %%
#Similarity in words :
word1 = wordnet.synsets("ship","n")[0]

word2 = wordnet.synsets("bike","n")[0]

#Check similarity :
print(word1.wup_similarity(word2))
# Out:
# 0.6956521739130435
